# %%
from sklearn.datasets import make_regression
x,y = make_regression(n_features=1, noise=5, n_samples=10000,random_state=1)
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regressor.predict(X_test)
# Out:
# array([ 107.63331378,   85.20289338, -137.68208746, ...,    7.27666025,
#         -66.81550678,  144.13214601])

# %%
regressor.score(X_test, y_test)
# Out:
# 0.9966682203247442

# %%
regressor.coef_
# Out:
# array([86.43461127])

# %%
regressor.intercept_
# Out:
# 0.06897851778392872

# %%
y_pred = regressor.predict(x)
y_pred
# Out:
# array([ 130.11174121,  -44.50818084, -167.83796224, ..., -142.34729233,
#          13.9017204 ,  -72.18184786])

# %%
plt.scatter(x,y,label='Actual')
plt.scatter(x,y_pred,label='Predicted')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()
